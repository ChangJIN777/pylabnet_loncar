# %%
from ODMR import ODMR
from pylabnet.hardware.awg import zi_hdawg  # Import the HDAWG driver wrapper used by EODMR_Si29.py.

# %%
file1 = "/Users/reneegeorge/Documents/Documents - renee’s MacBook Pro/Loncar Lab/Hu_Fridge/pylabnet_loncar/demo/zihdawg/dio_assignments"

# Run the expansion function
exp = ODMR(10e9, 11e9, 100, 100e-9, 1, 10, file1)

exp.configure(str(exp.sequence()))
meas = exp.launch()

f_data = exp.avg_counts(10.5e9)
# Out:
# Uploading to HDAWG...
#
#         const OFF = 0;
#         const TISA = 1 << 0;
#         const MW_IQ_PATH_SWITCH = 1 << 2;
#         const MW_OUTPUT_SWITCH = 1 << 3;
#         const MW_IQ_OUTPUT = MW_IQ_PATH_SWITCH | MW_OUTPUT_SWITCH;
#         const GREEN = 1 << 4;
#
#         var start_freq = 1000;
#         var stop_freq = 1100;
#         var freq_step = 1;
#
#         const t_green = 250000;
#         const t_read = 50000.0;
#         const sweep_len = 0;
#         const marker_buffer = 15.9999999;
#         const sweep_amp = 1;
#         const repeat_per_freq = 10;
#         const ionized_trsh = 100;
#
#
#
#         var el_perro_verde = 0;
#
#         wave sweep_pulse = sweep_amp * gauss(sweep_len, 1.0, sweep_len/2, sweep_len/6);
#         wave sweep_marker = join(marker(marker_buffer, 1),  marker(sweep_len, 1));
#
#         void READOUT() {
#             setTrigger(0b1);
#             setDIO(TISA);
#             wait(t_read);
#             setDIO(OFF);
# ...
