# %%
from pylabnet.network.client_server.si_tt import Client
# Out:
# c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\paramiko\pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\paramiko\transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
c = Client(host='192.168.50.101', port=12433)
# Out:
# Connection was refused.
# Please check that the server is running with hostname: 192.168.50.101, port: 12433
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c = Client(host='192.168.50.101', port=12433)
#
# File c:\users\user\documents\pylabnet_loncar\pylabnet\network\core\client_base.py:27, in ClientBase.__init__(self, host, port, key)
#      24 self._service = None
#      26 # Connect to server
# ---> 27 self.connect(host=host, port=port, key=key)
#
# File c:\users\user\documents\pylabnet_loncar\pylabnet\network\core\client_base.py:71, in ClientBase.connect(self, host, port, key)
#      69     else:
#      70         raise UnsupportedOSException()
# ---> 71     self._connection = rpyc.ssl_connect(
#      72         host=self._host,
#      73         port=self._port,
#      74         config={'allow_public_attrs': True},
#      75         keyfile=key,
#      76         certfile=key
#      77     )
#      78 self._service = self._connection.root
#      80 return 0
#
# File c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\rpyc\utils\factory.py:160, in ssl_connect(host, port, keyfile, certfile, ca_certs, cert_reqs, ssl_version, ciphers, service, config, ipv6, keepalive)
#     158 if ciphers is not None:
#     159     ssl_kwargs["ciphers"] = ciphers
# --> 160 s = SocketStream.ssl_connect(host, port, ssl_kwargs, ipv6=ipv6, keepalive=keepalive)
#     161 return connect_stream(s, service, config)
#
# File c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\rpyc\core\stream.py:212, in SocketStream.ssl_connect(cls, host, port, ssl_kwargs, **kwargs)
#     210 if kwargs.pop("ipv6", False):
#     211     kwargs["family"] = socket.AF_INET6
# --> 212 s = cls._connect(host, port, **kwargs)
#     213 try:
#     214     s2 = ssl.wrap_socket(s, **ssl_kwargs)
#
# File c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\rpyc\core\stream.py:125, in SocketStream._connect(cls, host, port, family, socktype, proto, timeout, nodelay, keepalive, attempts)
#     120 @classmethod
#     121 def _connect(cls, host, port, family=socket.AF_INET, socktype=socket.SOCK_STREAM,
#     122              proto=0, timeout=3, nodelay=False, keepalive=False, attempts=6):
#     123     family, socktype, proto, _, sockaddr = socket.getaddrinfo(host, port, family,
#     124                                                               socktype, proto)[0]
# --> 125     s = socket_backoff_connect(family, socktype, proto, sockaddr, timeout, attempts)
#     126     try:
#     127         if nodelay:
#
# File c:\Users\User\Documents\pylabnet_loncar\venv\lib\site-packages\rpyc\lib\__init__.py:131, in socket_backoff_connect(family, socktype, proto, addr, timeout, attempts)
#     129 try:
#     130     sock.settimeout(timeout)
# --> 131     sock.connect(addr)
#     132     connecting = False
#     133 except socket.timeout:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
c.start_rate_monitor(name="rate_1", ch_list=[2])

# %%
c.get_count_rate(name="rate_1")
# Out:
# array([705.31043017])
